# %%
# Task 1 Creat Travel Data Structures

# %%
# Tuple : Home base
home_base = ("Hyderabad ","India")
print(home_base)
# Out:
# ('Delhi', 'India')

# %%
# List of tuple : travel stops
stops = [("Paris","France"),("Rome","Itly"),("Berlin","Germany")]
print(stops)
# Out:
# [('Paris', 'France'), ('Rome', 'Itly'), ('Berlin', 'Germany')]

# %%
# Dictionary : itinerary
itinerary = {
    1:{"city": "Paris","activities": ["Visit Eiffel Tower","Louvre Museam","Seine River Cruise"],"budget":200},  
    2:{"city": "Rome","activities": ["Colosseum Tour","Vatican Museam"],"budget":350},
    3:{"city": "Berlin","activities": ["Brandenburg Gate","Berlin Wall Memorial"],"budget":250}}

print(itinerary)
# Out:
# {1: {'city': 'Paris', 'activities': ['Visit Eiffel Tower', 'Louvre Museam', 'Seine River Cruise'], 'budget': 200}, 2: {'city': 'Rome', 'activities': ['Colosseum Tour', 'Vatican Museam'], 'budget': 350}, 3: {'city': 'Berlin', 'activities': ['Brandenburg Gate', 'Berlin Wall Memorial'], 'budget': 250}}

# %%
# Set : packing list
packing_list = ("Passport","Cloths","Toothbrush","Phone Charger")
print(packing_list)

# %%
# Task 2 Write Two Functions

# %%
# add_day (day_number,city,activites,budget)
def add_day(day_number,city,activities,budget):itinerary [day_number] = {"city": city,"activities": activities,"budget": budget}

# %%
# update_budget(day_number,new_budget)
def update_budget(day_number, new_budget):itinerary [day_number]["budget"] = new_budget

# %%
add_day (4,"Amsterdam",["Canal Tour","Annie frank house"],175)
update_buget: (2,450)

# %%
# Task 3 Simple Edit Challenge
itinerary[2]["City"] = "Florance"
itinerary[1]["activities"][0] = "Noreth-Dame Catheral"
packing_list = list(packing_list)
packing_list.remove("Toothbrush")
stops.insert(1,("Barcelona","Sapin"))
print(itinerary)
print(stops)
print(packing_list)

# %%
update_budget(3,350)
packing_list.append("Wallet")
packing_list.append("Powr Bank")
itinerary[4]["activities"].append("Bike Tour")
print(itinerary)

# %%
print(packing_list)
